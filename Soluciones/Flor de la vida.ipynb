# %%
import numpy as np
% matplotlib inline
import matplotlib.pyplot as plt

plt.figure()
plt.axis("equal")
plt.axis("off")

angle = np.pi / 3
radius = 40
partial_rad = radius / 3

angles = np.arange(0, 2*np.pi, angle)

circle_angles = np.linspace(0, 2*np.pi)
c, s = np.cos(np.pi/6), np.sin(np.pi/6)
R = np.array([[c, -s], [s, c]])

for ang in angles:
    for r in range(0, 3):
        dx, dy = r*radius * np.cos(ang), r*radius * np.sin(ang)
        x = radius * np.cos(circle_angles) + dx
        y = radius * np.sin(circle_angles) + dy
        #coor = np.dot(R, np.hstack((x.reshape(len(x), 1), y.reshape(len(y), 1))).T)
        #plt.plot(coor[:, 0], coor[:, 1])
        plt.plot(x, y)

"""
rect_angles = np.arange(0, 2*np.pi, np.pi/6)
r = 2
for ang in rect_angles:
    dx, dy = r*radius * np.cos(ang), r*radius * np.sin(ang)
    x = radius * np.cos(circle_angles) + dx
    y = radius * np.sin(circle_angles) + dy
    plt.plot(x, y)
"""

plt.show()
